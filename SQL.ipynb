# %%
import pandas as pd

# %%
# !pip install psycopg2

# %%
import psycopg2

# %%
user = pd.read_sql(
    """
    SELECT * 
    FROM "user" 
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user.head()
# Out:
#     id  gender  age country               city  exp_group       os source
# 0  200       1   34  Russia          Degtyarsk          3  Android    ads
# 1  201       0   37  Russia             Abakan          0  Android    ads
# 2  202       1   17  Russia           Smolensk          4  Android    ads
# 3  203       0   18  Russia             Moscow          1      iOS    ads
# 4  204       0   36  Russia  Anzhero-Sudzhensk          3  Android    ads

# %%
print(f'{user.iloc[0]['id']} {user.iloc[0]['city']}')
# Out:
# 200 Degtyarsk

# %%
post = pd.read_sql(
    """
    SELECT DISTINCT topic
    FROM "post" 
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

post.head()
# Out:
#            topic
# 0           tech
# 1          covid
# 2          movie
# 3  entertainment
# 4       politics

# %%
post.shape[0]
# Out:
# 7

# %%
post
# Out:
#            topic
# 0           tech
# 1          covid
# 2          movie
# 3  entertainment
# 4       politics
# 5          sport
# 6       business

# %%
post['topic_length'] = post['topic'].apply(lambda x: len(x))
post
# Out:
#            topic  topic_length
# 0           tech             4
# 1          covid             5
# 2          movie             5
# 3  entertainment            13
# 4       politics             8
# 5          sport             5
# 6       business             8

# %%
ls = post.topic_length.tolist()
print(max(ls))
# Out:
# 13

# %%
i = post[
    post.topic_length == max(ls)
].index.tolist()
i = i[0]

print(f'{post.shape[0]} {post.iloc[i]['topic']}')
# Out:
# 7 entertainment

# %%
user
# Out:
#             id  gender  age country               city  exp_group       os  \
# 0          200       1   34  Russia          Degtyarsk          3  Android
# 1          201       0   37  Russia             Abakan          0  Android
# 2          202       1   17  Russia           Smolensk          4  Android
# 3          203       0   18  Russia             Moscow          1      iOS
# 4          204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...        ...     ...  ...     ...                ...        ...      ...
# 163200  168548       0   36  Russia        Kaliningrad          4  Android
# 163201  168549       0   18  Russia               Tula          2  Android
# 163202  168550       1   41  Russia      Yekaterinburg          4  Android
# 163203  168551       0   38  Russia             Moscow          3      iOS
# 163204  168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# ...

# %%
user_filt = pd.read_sql(
    """
    SELECT * 
    FROM "user" 
    WHERE age > 30 AND os = 'iOS'
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_filt.head()
# Out:
#     id  gender  age     country           city  exp_group   os source
# 0  212       1   47      Russia        Podolsk          0  iOS    ads
# 1  222       0   45      Russia      Ulyanovsk          0  iOS    ads
# 2  224       1   32      Russia  Yekaterinburg          2  iOS    ads
# 3  226       1   31      Russia         Moscow          4  iOS    ads
# 4  243       1   38  Kazakhstan      Ekibastuz          1  iOS    ads

# %%
print(f'{user_filt.iloc[0]['id']} {user_filt.iloc[0]['city']}')
# Out:
# 212 Podolsk

# %%
user_f = pd.read_sql(
    """
    SELECT * 
    FROM "user" 
    WHERE country NOT IN ('Russia') 
        AND (exp_group NOT IN (0, 3) OR city = 'Minsk')
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_f
# Out:
#            id  gender  age     country       city  exp_group       os   source
# 0         211       1   22     Belarus      Minsk          0      iOS      ads
# 1         213       1   22     Ukraine  Kamianske          2      iOS      ads
# 2         216       0   38     Ukraine       Lviv          1  Android      ads
# 3         218       1   25     Belarus      Minsk          2      iOS      ads
# 4         228       0   17  Azerbaijan       Baku          2      iOS      ads
# ...       ...     ...  ...         ...        ...        ...      ...      ...
# 12471  168477       1   20      Turkey     Ankara          4  Android  organic
# 12472  168524       1   17      Turkey     Ereğli          2  Android  organic
# 12473  168525       1   39     Ukraine  Pavlohrad          1      iOS  organic
# 12474  168527       1   20     Ukraine       Sumy          2      iOS  organic
# 12475  168544       1   18     Ukraine      Odesa          1      iOS  organic
#
# ...

# %%
user_f
# Out:
#            id  gender  age     country       city  exp_group       os   source
# 0         211       1   22     Belarus      Minsk          0      iOS      ads
# 1         213       1   22     Ukraine  Kamianske          2      iOS      ads
# 2         216       0   38     Ukraine       Lviv          1  Android      ads
# 3         218       1   25     Belarus      Minsk          2      iOS      ads
# 4         228       0   17  Azerbaijan       Baku          2      iOS      ads
# ...       ...     ...  ...         ...        ...        ...      ...      ...
# 12471  168477       1   20      Turkey     Ankara          4  Android  organic
# 12472  168524       1   17      Turkey     Ereğli          2  Android  organic
# 12473  168525       1   39     Ukraine  Pavlohrad          1      iOS  organic
# 12474  168527       1   20     Ukraine       Sumy          2      iOS  organic
# 12475  168544       1   18     Ukraine      Odesa          1      iOS  organic
#
# ...

# %%
l = user_f['id'].tolist()

for item in l:
    print(item, end=" ")
print()
# Out:
# 211 213 216 218 228 243 271 273 276 329 351 421 442 443 448 454 461 480 481 495 507 528 545 556 567 571 592 603 622 646 657 664 677 692 702 709 725 731 741 764 786 788 795 830 848 854 855 903 909 925 933 934 942 954 959 1000 1001 1018 1032 1049 1081 1085 1090 1095 1107 1109 1115 1124 1162 1173 1177 1195 1216 1219 1223 1230 1240 1258 1270 1274 1275 1276 1292 1311 1312 1317 1318 1366 1375 1385 1402 1433 1445 1449 1450 1452 1458 1459 1478 1490 1514 1515 1524 1538 1543 1562 1570 1590 1591 1594 1600 1696 1712 1713 1714 1718 1724 1725 1727 1737 1753 1756 1781 1792 1799 1809 1823 1824 1844 1852 1881 1926 1927 1963 1975 1995 1999 2010 2013 2054 2063 2071 2097 2101 2110 2122 2128 2130 2160 2175 2209 2210 2214 2245 2247 2252 2262 2268 2278 2280 2284 2296 2308 2313 2350 2351 2354 2358 2379 2382 2387 2397 2424 2429 2438 2442 2446 2454 2457 2463 2495 2499 2503 2509 2515 2516 2525 2528 2531 2533 2570 2590 2611 2616 2622 2629 2654 2676 2679 2685 2722 2729 2730 2731 2818 2835 2842 2848 2864 2865 286
# ...

# %%
user_country = pd.read_sql(
    """
    SELECT country, AVG(age)
    FROM "user" 
    GROUP BY country
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_country
# Out:
#         country        avg
# 0    Azerbaijan  26.784695
# 1       Belarus  27.277255
# 2        Cyprus  28.070588
# 3       Estonia  28.146067
# 4       Finland  27.131957
# 5    Kazakhstan  27.224464
# 6        Latvia  27.217143
# 7        Russia  27.188387
# 8   Switzerland  27.950617
# 9        Turkey  27.452055
# 10      Ukraine  27.258310

# %%
user_country = user_country.set_index('country')

# %%
user_country
# Out:
#                    avg
# country
# Azerbaijan   26.784695
# Belarus      27.277255
# Cyprus       28.070588
# Estonia      28.146067
# Finland      27.131957
# Kazakhstan   27.224464
# Latvia       27.217143
# Russia       27.188387
# Switzerland  27.950617
# Turkey       27.452055
# Ukraine      27.258310

# %%
num = user_country.loc['Cyprus']['avg']

print(round(num, 2))
# Out:
# 28.07

# %%
user
# Out:
#             id  gender  age country               city  exp_group       os  \
# 0          200       1   34  Russia          Degtyarsk          3  Android
# 1          201       0   37  Russia             Abakan          0  Android
# 2          202       1   17  Russia           Smolensk          4  Android
# 3          203       0   18  Russia             Moscow          1      iOS
# 4          204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...        ...     ...  ...     ...                ...        ...      ...
# 163200  168548       0   36  Russia        Kaliningrad          4  Android
# 163201  168549       0   18  Russia               Tula          2  Android
# 163202  168550       1   41  Russia      Yekaterinburg          4  Android
# 163203  168551       0   38  Russia             Moscow          3      iOS
# 163204  168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# ...

# %%
user_group = pd.read_sql(
    """
    SELECT exp_group, os, COUNT(id) AS total_users, MAX(age) AS max_age, MIN(age) AS min_age
    FROM "user" 
    GROUP BY exp_group, os
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_group
# Out:
#    exp_group       os  total_users  max_age  min_age
# 0          0  Android        21234       95       14
# 1          0      iOS        11489       79       14
# 2          1  Android        21232       92       14
# 3          1      iOS        11406       87       14
# 4          2  Android        21102       78       14
# 5          2      iOS        11512       74       14
# 6          3  Android        21319       84       14
# 7          3      iOS        11449       85       14
# 8          4  Android        21085       84       14
# 9          4      iOS        11377       78       14

# %%
user_group.to_csv('user_group.csv', sep=',', index=False)

# %%
post = pd.read_sql(
    """
    SELECT *
    FROM "post" 
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

post.head()
# Out:
#    id                                               text     topic
# 0   1  UK economy facing major risks\n\nThe UK manufa...  business
# 1   2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2   3  Asian quake hits European shares\n\nShares in ...  business
# 3   4  India power shares jump on debut\n\nShares in ...  business
# 4   5  Lacroix label bought by US firm\n\nLuxury good...  business

# %%
post_group = pd.read_sql(
    """
    SELECT topic, MAX(LENGTH(text))
    FROM "post"
    GROUP BY topic 
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

post_group
# Out:
#            topic    max
# 0           tech  16063
# 1          covid    148
# 2          movie  10234
# 3  entertainment  19004
# 4       politics  25392
# 5          sport   9438
# 6       business   5378

# %%
post_group = post_group.set_index('max')

# %%
post_group
# Out:
#                topic
# max
# 16063           tech
# 148            covid
# 10234          movie
# 19004  entertainment
# 25392       politics
# 9438           sport
# 5378        business

# %%
ls = post_group.index.tolist()

i = 0
for el in ls:
    if el > 25000:
        i = el

print(post_group.loc[i]['topic'])
# Out:
# politics

# %%
user
# Out:
#             id  gender  age country               city  exp_group       os  \
# 0          200       1   34  Russia          Degtyarsk          3  Android
# 1          201       0   37  Russia             Abakan          0  Android
# 2          202       1   17  Russia           Smolensk          4  Android
# 3          203       0   18  Russia             Moscow          1      iOS
# 4          204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...        ...     ...  ...     ...                ...        ...      ...
# 163200  168548       0   36  Russia        Kaliningrad          4  Android
# 163201  168549       0   18  Russia               Tula          2  Android
# 163202  168550       1   41  Russia      Yekaterinburg          4  Android
# 163203  168551       0   38  Russia             Moscow          3      iOS
# 163204  168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# ...

# %%
user_10 = pd.read_sql(
    """
    SELECT country, COUNT(id)
    FROM "user"
    GROUP BY country
    HAVING COUNT(id) > 1000
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_10
# Out:
#       country   count
# 0  Azerbaijan    1542
# 1     Belarus    3293
# 2     Finland    1599
# 3  Kazakhstan    3172
# 4      Russia  143035
# 5      Turkey    1606
# 6     Ukraine    8273

# %%
user_10 = user_10.set_index('count')

# %%
user_10
# Out:
#            country
# count
# 1542    Azerbaijan
# 3293       Belarus
# 1599       Finland
# 3172    Kazakhstan
# 143035      Russia
# 1606        Turkey
# 8273       Ukraine

# %%
ls = user_10.index.tolist()

print(user_10.loc[min(ls)]['country'])
# Out:
# Azerbaijan

# %%
user_12 = pd.read_sql(
    """
    SELECT exp_group, COUNT(id)
    FROM "user"
    WHERE city = 'Moscow'
    GROUP BY exp_group
    HAVING AVG(age) > 27.2
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_12
# Out:
#    exp_group  count
# 0          1   4414
# 1          3   4378

# %%
ls = user_12['count'].tolist()

for el in ls:
    print(el, end=' ')
# Out:
# 4414 4378

# %%
post
# Out:
#         id                                               text     topic
# 0        1  UK economy facing major risks\n\nThe UK manufa...  business
# 1        2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2        3  Asian quake hits European shares\n\nShares in ...  business
# 3        4  India power shares jump on debut\n\nShares in ...  business
# 4        5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...    ...                                                ...       ...
# 7018  7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019  7316  I give this movie 2 stars purely because of it...     movie
# 7020  7317  I cant believe this film was allowed to be mad...     movie
# 7021  7318  The version I saw of this film was the Blockbu...     movie
# 7022  7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %%
post_13 = pd.read_sql(
    """
    SELECT topic, COUNT(text)
    FROM "post"
    GROUP BY topic
    ORDER BY COUNT(text) DESC
    LIMIT 3
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

post_13
# Out:
#    topic  count
# 0  movie   3000
# 1  covid   1799
# 2  sport    510

# %%
ls = post_13.topic.tolist()
ls
# Out:
# ['movie', 'covid', 'sport']

# %%
for el in ls:
    print(el, end=' ')
# Out:
# movie covid sport

# %%
user
# Out:
#             id  gender  age country               city  exp_group       os  \
# 0          200       1   34  Russia          Degtyarsk          3  Android
# 1          201       0   37  Russia             Abakan          0  Android
# 2          202       1   17  Russia           Smolensk          4  Android
# 3          203       0   18  Russia             Moscow          1      iOS
# 4          204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...        ...     ...  ...     ...                ...        ...      ...
# 163200  168548       0   36  Russia        Kaliningrad          4  Android
# 163201  168549       0   18  Russia               Tula          2  Android
# 163202  168550       1   41  Russia      Yekaterinburg          4  Android
# 163203  168551       0   38  Russia             Moscow          3      iOS
# 163204  168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# ...

# %%
user_14 = pd.read_sql(
    """
    SELECT id, city, age, exp_group
    FROM "user"
    WHERE city = 'Voronezh'
    ORDER BY age DESC, exp_group ASC
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

user_14
# Out:
#           id      city  age  exp_group
# 0      89990  Voronezh   71          0
# 1       2441  Voronezh   71          3
# 2      14184  Voronezh   66          3
# 3      35093  Voronezh   65          0
# 4      77284  Voronezh   64          4
# ...      ...       ...  ...        ...
# 1369  151841  Voronezh   14          4
# 1370  116446  Voronezh   14          4
# 1371   18278  Voronezh   14          4
# 1372  110611  Voronezh   14          4
# 1373   29604  Voronezh   14          4
#
# [1374 rows x 4 columns]

# %%
feed_action = pd.read_sql(
    """
    SELECT * 
    FROM "feed_action" 
    LIMIT 10
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

feed_action
# Out:
#    user_id  post_id action                time  id
# 0   120922     2390   like 2021-11-19 23:56:41   1
# 1    31903     2277   view 2021-11-19 23:56:41   2
# 2   120413     2320   view 2021-11-19 23:56:42   3
# 3     4846     2321   view 2021-11-19 23:56:43   4
# 4   116562     2395   view 2021-11-19 23:56:43   5
# 5   137360     2180   view 2021-11-19 23:56:43   6
# 6      220     2377   view 2021-11-19 23:56:43   7
# 7    24741     2344   view 2021-11-19 23:56:43   8
# 8   115213     2212   view 2021-11-19 23:56:43   9
# 9    31033     2272   view 2021-11-19 23:56:43  10

# %%
user
# Out:
#             id  gender  age country               city  exp_group       os  \
# 0          200       1   34  Russia          Degtyarsk          3  Android
# 1          201       0   37  Russia             Abakan          0  Android
# 2          202       1   17  Russia           Smolensk          4  Android
# 3          203       0   18  Russia             Moscow          1      iOS
# 4          204       0   36  Russia  Anzhero-Sudzhensk          3  Android
# ...        ...     ...  ...     ...                ...        ...      ...
# 163200  168548       0   36  Russia        Kaliningrad          4  Android
# 163201  168549       0   18  Russia               Tula          2  Android
# 163202  168550       1   41  Russia      Yekaterinburg          4  Android
# 163203  168551       0   38  Russia             Moscow          3      iOS
# 163204  168552       1   16  Russia        Ivanteyevka          4  Android
#
#          source
# 0           ads
# 1           ads
# ...

# %%
post
# Out:
#         id                                               text     topic
# 0        1  UK economy facing major risks\n\nThe UK manufa...  business
# 1        2  Aids and climate top Davos agenda\n\nClimate c...  business
# 2        3  Asian quake hits European shares\n\nShares in ...  business
# 3        4  India power shares jump on debut\n\nShares in ...  business
# 4        5  Lacroix label bought by US firm\n\nLuxury good...  business
# ...    ...                                                ...       ...
# 7018  7315  OK, I would not normally watch a Farrelly brot...     movie
# 7019  7316  I give this movie 2 stars purely because of it...     movie
# 7020  7317  I cant believe this film was allowed to be mad...     movie
# 7021  7318  The version I saw of this film was the Blockbu...     movie
# 7022  7319  Piece of subtle art. Maybe a masterpiece. Doub...     movie
#
# [7023 rows x 3 columns]

# %% [markdown]
# Отберите post_id, time, age и os пользователя для всех лайков пользователей из Омска. Отсортируйте результаты по убыванию времени действия и загрузите в LMS первые 100 значений в формате CSV (сепаратор "запятая", колонки с теми же названиями, что и в задании).

# %%
join_15 = pd.read_sql(
    """
    SELECT f.post_id, f.time, u.age, u.os
    FROM feed_action f
    JOIN "user" u on f.user_id = u.id
    WHERE f.action = 'like' AND u.city = 'Omsk'
    ORDER BY f.time DESC
    LIMIT 100
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

join_15
# Out:
#     post_id                time  age       os
# 0      7159 2022-01-26 23:59:54   17  Android
# 1      7184 2022-01-26 23:56:30   17  Android
# 2      7265 2022-01-26 23:56:03   17  Android
# 3      7256 2022-01-26 23:55:24   17  Android
# 4      7080 2022-01-26 23:55:12   17  Android
# ..      ...                 ...  ...      ...
# 95     7256 2022-01-26 22:43:54   31  Android
# 96     7316 2022-01-26 22:42:54   31  Android
# 97     7319 2022-01-26 22:39:35   36      iOS
# 98     7268 2022-01-26 22:39:04   36      iOS
# 99     7226 2022-01-26 22:35:11   36      iOS
#
# [100 rows x 4 columns]

# %%
join_15.to_csv('join_15.csv', sep=',', index = False)

# %% [markdown]
# Найдите город, пользователи которого в возрасте 36 лет 2021-12-01 числа просмотрели запись на тему covid меньше всего раз относительно других городов. Введите его название на английском.

# %%
join_16 = pd.read_sql(
    """
    SELECT u.city, COUNT(f.post_id)
    FROM "feed_action" f
    JOIN "user" u on f.user_id = u.id
    JOIN "post" p on f.post_id = p.id
    WHERE u.age = 36 and date(f.time) = '2021-12-01' and p.topic = 'covid'
    GROUP BY u.city
    ORDER BY COUNT(u.id) 
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

join_16
# Out:
#                  city  count
# 0         Arkhangelsk      6
# 1            Fryazino      9
# 2          Apsheronsk     10
# 3               Lubny     10
# 4                Kirs     11
# ..                ...    ...
# 163  Nizhniy Novgorod    151
# 164          Belgorod    170
# 165       Novosibirsk    212
# 166  Saint Petersburg    281
# 167            Moscow   1975
#
# [168 rows x 2 columns]

# %% [markdown]
# SELECT   --столбцы или * для выбора всех столбцов; обязательный запрос
# FROM     --таблица; обязательный запрос
# WHERE    -- условие/фильтрация; необязательный запрос
# GROUP BY --столбец, по которому хотим сгруппировать данные; необязательный запрос
# HAVING   --условие/фильтрация на уровне сгруппированных данных; необязательно
# ORDER BY --столбец, по которому хотим отсортировать вывод; необязательно

# %% [markdown]
# Напишите SQL запрос, используя который вы получите:
# - топ N постов по лайкам,
# - количество пролайкавших пользователей,
# - время последнего лайка.

# %%
join_17 = pd.read_sql(
    """
    SELECT p.id, p.text, COUNT(f.action), MAX(f.time)
    FROM feed_action f
    JOIN "post" p ON f.post_id = p.id
    WHERE f.action = 'like'
    GROUP BY p.id 
    ORDER BY COUNT(f.action) DESC
    LIMIT 10
    """,
    con="postgresql://robot-startml-ro:pheiph0hahj1Vaif@"
        "postgres.lab.karpov.courses:6432/startml"
)

join_17
# Out:
#      id                                               text  count  \
# 0  4866  It could have been a morbidly fascinating look...  31714
# 1  5127  Ive seen NSNA just after Ive seen all Roger Mo...  29637
# 2  6448  No, Im not joking around. If you ever, EVER, h...  27939
# 3  6498  As a matter of fact, this is one of those movi...  27729
# 4  6513  Rita Hayworth plays a Brooklyn nightclub dance...  27686
# 5  3192  With the KCCA #COVID19 Response Hub, you can t...  26507
# 6  6314  I believe the reason this movie did not get th...  26478
# 7  6864  this is one of the finest movies i have ever s...  24156
# 8  5413  Im not here to tell you Armored is Kubrickian,...  23441
# 9  5165  This is just a case of a previously worthless ...  22596
#
#                   max
# 0 2022-01-01 13:57:43
# 1 2022-01-05 13:52:17
# 2 2022-01-22 05:50:39
# 3 2022-01-22 21:45:11
# 4 2022-01-22 19:59:52
# 5 2021-12-06 19:57:50
# 6 2022-01-20 07:46:21
# 7 2022-01-26 23:52:48
# 8 2022-01-07 09:57:07
# ...
